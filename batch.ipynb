# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
# Define the CNN model
def create_cnn_model(input_shape=(256, 256, 3), num_classes=78):
    model = models.Sequential()

    # Convolutional layers
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Flatten layer
    model.add(layers.Flatten())

    # Dense layers
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))  # Dropout for regularization

    model.add(layers.Dense(num_classes, activation='softmax'))

    # Compile the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Specify the paths for training, teasting and validation data
train_data_dir = 'C:\\Users\\Amrutha Y\\Desktop\\Train'
validation_data_dir = 'C:\\Users\\Amrutha Y\\Desktop\\Validation'
test_data_dir = 'C:\\Users\\Amrutha Y\\Desktop\\Test'
# Image data augmentation to improve model generalization
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# Set batch size
batch_size = 32

# Load and augment training data
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(256, 256),
    batch_size=batch_size,
    class_mode='categorical')

# Load validation data
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(256, 256),
    batch_size=batch_size,
    class_mode='categorical')
# Load and augment test data
test_generator = test_datagen.flow_from_directory(
    test_data_dir,  # Specify the path to your test data
    target_size=(256, 256),
    batch_size=batch_size,
    class_mode='categorical')

# Define a ModelCheckpoint callback
checkpoint = ModelCheckpoint('model_checkpoint.h5', 
                             save_best_only=True, 
                             monitor='val_loss', 
                             mode='min', 
                             verbose=1)

# Create the CNN model
cnn_model = create_cnn_model()

# Train the model
history = cnn_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // 32,
    epochs=100,  # Adjust the number of epochs as needed
    callbacks=[checkpoint],
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // 32)

# Evaluate the model on the test data
test_loss, test_accuracy = cnn_model.evaluate(test_generator)

print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Loss: {test_loss}")
# Evaluate the model on the train data
train_loss, train_accuracy = cnn_model.evaluate(train_generator)

print(f"Train Accuracy: {train_accuracy * 100:.2f}%")
print(f"Train Loss: {train_loss}")

# Save the trained model
actual_model=cnn_model.save('batch_plant_prediction_model.h5')
# Out:
# Found 1950 images belonging to 78 classes.
# Found 546 images belonging to 78 classes.
# Found 468 images belonging to 78 classes.
# Epoch 1/100
# 60/60 [==============================] - ETA: 0s - loss: 4.5433 - accuracy: 0.0495
# Epoch 1: val_loss improved from inf to 4.73501, saving model to model_checkpoint.h5
# 60/60 [==============================] - 230s 4s/step - loss: 4.5433 - accuracy: 0.0495 - val_loss: 4.7350 - val_accuracy: 0.0110
# Epoch 2/100
# 60/60 [==============================] - ETA: 0s - loss: 3.6410 - accuracy: 0.1627
# Epoch 2: val_loss did not improve from 4.73501
# 60/60 [==============================] - 227s 4s/step - loss: 3.6410 - accuracy: 0.1627 - val_loss: 5.1836 - val_accuracy: 0.0184
# Epoch 3/100
# 60/60 [==============================] - ETA: 0s - loss: 3.1696 - accuracy: 0.2450
# Epoch 3: val_loss did not improve from 4.73501
# ...

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
# Define the CNN model
def create_cnn_model(input_shape=(256, 256, 3), num_classes=78):
    model = models.Sequential()

    # Convolutional layers
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Flatten layer
    model.add(layers.Flatten())

    # Dense layers
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))  # Dropout for regularization

    model.add(layers.Dense(num_classes, activation='softmax'))

    # Compile the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Specify the paths for training, teasting and validation data
train_data_dir = 'C:\\Users\\Amrutha Y\\Desktop\\Train'
validation_data_dir = 'C:\\Users\\Amrutha Y\\Desktop\\Validation'
test_data_dir = 'C:\\Users\\Amrutha Y\\Desktop\\Test'
# Image data augmentation to improve model generalization
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# Set batch size
batch_size = 32

# Load and augment training data
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(256, 256),
    batch_size=batch_size,
    class_mode='categorical')

# Load validation data
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(256, 256),
    batch_size=batch_size,
    class_mode='categorical')
# Load and augment test data
test_generator = test_datagen.flow_from_directory(
    test_data_dir,  # Specify the path to your test data
    target_size=(256, 256),
    batch_size=batch_size,
    class_mode='categorical')

# Define a ModelCheckpoint callback
checkpoint = ModelCheckpoint('model_checkpoint.h5', 
                             save_best_only=True, 
                             monitor='val_loss', 
                             mode='min', 
                             verbose=1)

# Create the CNN model
cnn_model = create_cnn_model()

# Train the model
history = cnn_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // 32,
    epochs=50,  # Adjust the number of epochs as needed
    callbacks=[checkpoint],
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // 32)

# Evaluate the model on the test data
test_loss, test_accuracy = cnn_model.evaluate(test_generator)

print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Loss: {test_loss}")
# Evaluate the model on the train data
train_loss, train_accuracy = cnn_model.evaluate(train_generator)

print(f"Train Accuracy: {train_accuracy * 100:.2f}%")
print(f"Train Loss: {train_loss}")

# Save the trained model
actual_model=cnn_model.save('batch_plant_prediction_model1.h5')
# Out:
# Found 1950 images belonging to 78 classes.
# Found 546 images belonging to 78 classes.
# Found 468 images belonging to 78 classes.
# Epoch 1/50
# 60/60 [==============================] - ETA: 0s - loss: 4.4249 - accuracy: 0.0740
# Epoch 1: val_loss improved from inf to 5.10310, saving model to model_checkpoint.h5
# 60/60 [==============================] - 724s 12s/step - loss: 4.4249 - accuracy: 0.0740 - val_loss: 5.1031 - val_accuracy: 0.0239
# Epoch 2/50
# 60/60 [==============================] - ETA: 0s - loss: 3.5831 - accuracy: 0.1632
# Epoch 2: val_loss improved from 5.10310 to 4.50083, saving model to model_checkpoint.h5
# 60/60 [==============================] - 311s 5s/step - loss: 3.5831 - accuracy: 0.1632 - val_loss: 4.5008 - val_accuracy: 0.0129
# Epoch 3/50
# 60/60 [==============================] - ETA: 0s - loss: 3.2839 - accuracy: 0.2195
# Epoch 3: val_loss did not improve from 4.50083
# ...

# %%
# Load the saved model
from tensorflow.keras.models import load_model
import cv2
import numpy as np
import os
# Replace 'plant_prediction_model.h5' with the actual path to your saved model file
model_path = 'batch_plant_prediction_model1.h5'
trained_model = load_model(model_path)

# Now, you can use the model for prediction on new data
def image_predict(new_image_path):
# Load the plant image
# image_path = 'plant1.jpg'
    

# Example: Load and preprocess a new image for prediction
# new_image_path = '120.jpg'
    img = cv2.imread(new_image_path)
    img = cv2.resize(img, (256, 256))  # Resize for the model's expected input size
    img = img / 255.0  # Normalize pixel values to be between 0 and 1

# Reshape the image to match the input shape expected by the model
    img = img.reshape((1,) + img.shape)

# Make predictions
    predictions = trained_model.predict(img)

# The 'predictions' variable now contains the model's output, which you can interpret as needed
# For example, you can get the predicted class label as follows:
    predicted_class = np.argmax(predictions)

# Display the results
    print("Predicted Class:", predicted_class)
#     print("Predictions (raw output):", predictions)
folder_path = 'C:\\Users\\Amrutha Y\\Desktop\\Train\\Amla'
# Iterate through all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(('.jpg', '.jpeg', '.png')):
        # Load the plant image
        print(filename)
        image_path = os.path.join(folder_path, filename)
        image_predict(image_path)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Load the saved model
loaded_model = tf.keras.models.load_model('batch_plant_prediction_model1.h5')

# Specify the paths for testing data
test_data_dir = 'C:\\Users\\Amrutha Y\\Desktop\\Test'

# Load and preprocess test data
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(256, 256),
#     batch_siz=32,
    class_mode='categorical')

# Make predictions on the test data
predictions = loaded_model.predict(test_generator)

# Get the class labels
class_labels = list(test_generator.class_indices.keys())

# Get the original class names for the test data
original_class_names = test_generator.filenames

# Get the predicted class indices
predicted_class_indices = np.argmax(predictions, axis=1)

# Print original class name and predicted class in number
for i in range(len(original_class_names)):
    original_class_name = original_class_names[i].split('\\')[0]  # Extracting class name from the path
    predicted_class = predicted_class_indices[i]
    print(f"Original class: {original_class_name}, Predicted class (in number): {predicted_class}")
# Out:
# Found 468 images belonging to 78 classes.
# 15/15 [==============================] - 36s 2s/step
# Original class: Aloevera, Predicted class (in number): 73
# Original class: Aloevera, Predicted class (in number): 41
# Original class: Aloevera, Predicted class (in number): 15
# Original class: Aloevera, Predicted class (in number): 64
# Original class: Aloevera, Predicted class (in number): 63
# Original class: Aloevera, Predicted class (in number): 2
# Original class: Amla, Predicted class (in number): 26
# Original class: Amla, Predicted class (in number): 71
# Original class: Amla, Predicted class (in number): 66
# Original class: Amla, Predicted class (in number): 59
# Original class: Amla, Predicted class (in number): 61
# Original class: Amla, Predicted class (in number): 64
# Original class: Amruthaballi, Predicted class (in number): 68
# Original class: Amruthaballi, Predicted class (in number): 27
# Original class: Amruthaballi, Predicted class (in number): 42
# ...

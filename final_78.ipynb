# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
# Define the CNN model
def create_cnn_model(input_shape=(256, 256, 3), num_classes=78):
    model = models.Sequential()

    # Convolutional layers
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Flatten layer
    model.add(layers.Flatten())

    # Dense layers
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))  # Dropout for regularization

    model.add(layers.Dense(num_classes, activation='softmax'))

    # Compile the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Specify the paths for training, teasting and validation data
train_data_dir = 'C:\\Users\\Amrutha Y\\Desktop\\Train'
validation_data_dir = 'C:\\Users\\Amrutha Y\\Desktop\\Validation'
test_data_dir = 'C:\\Users\\Amrutha Y\\Desktop\\Test'
# Image data augmentation to improve model generalization
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# Set batch size
batch_size = 32

# Load and augment training data
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(256, 256),
    batch_size=batch_size,
    class_mode='categorical')

# Load validation data
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(256, 256),
    batch_size=batch_size,
    class_mode='categorical')
# Load and augment test data
test_generator = test_datagen.flow_from_directory(
    test_data_dir,  # Specify the path to your test data
    target_size=(256, 256),
    batch_size=batch_size,
    class_mode='categorical')

# Define a ModelCheckpoint callback
checkpoint = ModelCheckpoint('model_checkpoint.h5', 
                             save_best_only=True, 
                             monitor='val_loss', 
                             mode='min', 
                             verbose=1)

# Create the CNN model
cnn_model = create_cnn_model()

# Train the model
history = cnn_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // 32,
    epochs=100,  # Adjust the number of epochs as needed
    callbacks=[checkpoint],
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // 32)
# Evaluate the model on the test data
test_loss, test_accuracy = cnn_model.evaluate(test_generator)

print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Loss: {test_loss}")
# Save the trained model
actual_model=cnn_model.save('plant_prediction_model.h5')
# Out:
# Found 1950 images belonging to 78 classes.
# Found 546 images belonging to 78 classes.
# Found 468 images belonging to 78 classes.
# Epoch 1/100
# 60/60 [==============================] - ETA: 0s - loss: 4.5380 - accuracy: 0.0083
# Epoch 1: val_loss improved from inf to 4.35665, saving model to model_checkpoint.h5
# 60/60 [==============================] - 640s 11s/step - loss: 4.5380 - accuracy: 0.0083 - val_loss: 4.3567 - val_accuracy: 0.0147
# Epoch 2/100
# 60/60 [==============================] - ETA: 0s - loss: 4.3526 - accuracy: 0.0151
# Epoch 2: val_loss improved from 4.35665 to 4.33345, saving model to model_checkpoint.h5
# 60/60 [==============================] - 2968s 50s/step - loss: 4.3526 - accuracy: 0.0151 - val_loss: 4.3335 - val_accuracy: 0.0294
# Epoch 3/100
# 60/60 [==============================] - ETA: 0s - loss: 4.2885 - accuracy: 0.0313
# Epoch 3: val_loss improved from 4.33345 to 4.25993, saving model to model_checkpoint.h5
# 60/60 [==============================] - 234s 4s/step - loss: 4.2885 - accuracy: 0.0313 - val_loss: 4.2599 - val_accuracy: 0.0386
# Epoch 4/100
# 60/60 [==============================] - ETA: 0s - loss: 4.2931 - accuracy: 0.0313
# Epoch 4: val_loss did not improve from 4.25993
# 60/60 [==============================] - 238s 4s/step - loss: 4.2931 - accuracy: 0.0313 - val_loss: 4.2801 - val_accuracy: 0.0331
# Epoch 5/100
# 60/60 [==============================] - ETA: 0s - loss: 4.2335 - accuracy: 0.0401
# Epoch 5: val_loss improved from 4.25993 to 4.20365, saving model to model_checkpoint.h5
# 60/60 [==============================] - 237s 4s/step - loss: 4.2335 - accuracy: 0.0401 - val_loss: 4.2036 - val_accuracy: 0.0496
# Epoch 6/100
# 60/60 [==============================] - ETA: 0s - loss: 4.1240 - accuracy: 0.0652
# Epoch 6: val_loss improved from 4.20365 to 4.11932, saving model to model_checkpoint.h5
# 60/60 [==============================] - 237s 4s/step - loss: 4.1240 - accuracy: 0.0652 - val_loss: 4.1193 - val_accuracy: 0.0827
# Epoch 7/100
# 60/60 [==============================] - ETA: 0s - loss: 4.0278 - accuracy: 0.0865
# Epoch 7: val_loss improved from 4.11932 to 3.91890, saving model to model_checkpoint.h5
# 60/60 [==============================] - 240s 4s/step - loss: 4.0278 - accuracy: 0.0865 - val_loss: 3.9189 - val_accuracy: 0.1121
# Epoch 8/100
# 60/60 [==============================] - ETA: 0s - loss: 3.9155 - accuracy: 0.1017
# Epoch 8: val_loss improved from 3.91890 to 3.83184, saving model to model_checkpoint.h5
# 60/60 [==============================] - 240s 4s/step - loss: 3.9155 - accuracy: 0.1017 - val_loss: 3.8318 - val_accuracy: 0.1342
# Epoch 9/100
# 60/60 [==============================] - ETA: 0s - loss: 3.7438 - accuracy: 0.1184
# Epoch 9: val_loss improved from 3.83184 to 3.69569, saving model to model_checkpoint.h5
# 60/60 [==============================] - 240s 4s/step - loss: 3.7438 - accuracy: 0.1184 - val_loss: 3.6957 - val_accuracy: 0.1710
# Epoch 10/100
# 60/60 [==============================] - ETA: 0s - loss: 3.6069 - accuracy: 0.1543
# Epoch 10: val_loss improved from 3.69569 to 3.58257, saving model to model_checkpoint.h5
# 60/60 [==============================] - 245s 4s/step - loss: 3.6069 - accuracy: 0.1543 - val_loss: 3.5826 - val_accuracy: 0.1636
# Epoch 11/100
# 60/60 [==============================] - ETA: 0s - loss: 3.4677 - accuracy: 0.1783
# Epoch 11: val_loss improved from 3.58257 to 3.50518, saving model to model_checkpoint.h5
# 60/60 [==============================] - 241s 4s/step - loss: 3.4677 - accuracy: 0.1783 - val_loss: 3.5052 - val_accuracy: 0.1801
# Epoch 12/100
# 60/60 [==============================] - ETA: 0s - loss: 3.3166 - accuracy: 0.1992
# Epoch 12: val_loss improved from 3.50518 to 3.29482, saving model to model_checkpoint.h5
# 60/60 [==============================] - 240s 4s/step - loss: 3.3166 - accuracy: 0.1992 - val_loss: 3.2948 - val_accuracy: 0.2298
# Epoch 13/100
# 60/60 [==============================] - ETA: 0s - loss: 3.1734 - accuracy: 0.2221
# Epoch 13: val_loss improved from 3.29482 to 3.11562, saving model to model_checkpoint.h5
# 60/60 [==============================] - 241s 4s/step - loss: 3.1734 - accuracy: 0.2221 - val_loss: 3.1156 - val_accuracy: 0.2757
# Epoch 14/100
# 60/60 [==============================] - ETA: 0s - loss: 3.0066 - accuracy: 0.2435
# Epoch 14: val_loss improved from 3.11562 to 3.00761, saving model to model_checkpoint.h5
# 60/60 [==============================] - 242s 4s/step - loss: 3.0066 - accuracy: 0.2435 - val_loss: 3.0076 - val_accuracy: 0.2757
# Epoch 15/100
# 60/60 [==============================] - ETA: 0s - loss: 2.8317 - accuracy: 0.2805
# Epoch 15: val_loss improved from 3.00761 to 2.99751, saving model to model_checkpoint.h5
# 60/60 [==============================] - 243s 4s/step - loss: 2.8317 - accuracy: 0.2805 - val_loss: 2.9975 - val_accuracy: 0.2812
# Epoch 16/100
# 60/60 [==============================] - ETA: 0s - loss: 2.7434 - accuracy: 0.3092
# Epoch 16: val_loss improved from 2.99751 to 2.81766, saving model to model_checkpoint.h5
# 60/60 [==============================] - 241s 4s/step - loss: 2.7434 - accuracy: 0.3092 - val_loss: 2.8177 - val_accuracy: 0.3621
# Epoch 17/100
# 60/60 [==============================] - ETA: 0s - loss: 2.5510 - accuracy: 0.3472
# Epoch 17: val_loss improved from 2.81766 to 2.72544, saving model to model_checkpoint.h5
# 60/60 [==============================] - 239s 4s/step - loss: 2.5510 - accuracy: 0.3472 - val_loss: 2.7254 - val_accuracy: 0.3676
# Epoch 18/100
# 60/60 [==============================] - ETA: 0s - loss: 2.4399 - accuracy: 0.3603
# Epoch 18: val_loss improved from 2.72544 to 2.71118, saving model to model_checkpoint.h5
# 60/60 [==============================] - 240s 4s/step - loss: 2.4399 - accuracy: 0.3603 - val_loss: 2.7112 - val_accuracy: 0.3787
# Epoch 19/100
# 60/60 [==============================] - ETA: 0s - loss: 2.3198 - accuracy: 0.3822
# Epoch 19: val_loss did not improve from 2.71118
# 60/60 [==============================] - 239s 4s/step - loss: 2.3198 - accuracy: 0.3822 - val_loss: 2.7191 - val_accuracy: 0.3566
# Epoch 20/100
# 60/60 [==============================] - ETA: 0s - loss: 2.2375 - accuracy: 0.3926
# Epoch 20: val_loss improved from 2.71118 to 2.63067, saving model to model_checkpoint.h5
# 60/60 [==============================] - 239s 4s/step - loss: 2.2375 - accuracy: 0.3926 - val_loss: 2.6307 - val_accuracy: 0.3676
# Epoch 21/100
# 60/60 [==============================] - ETA: 0s - loss: 2.1720 - accuracy: 0.4296
# Epoch 21: val_loss did not improve from 2.63067
# 60/60 [==============================] - 240s 4s/step - loss: 2.1720 - accuracy: 0.4296 - val_loss: 2.7051 - val_accuracy: 0.4062
# Epoch 22/100
# 60/60 [==============================] - ETA: 0s - loss: 2.1208 - accuracy: 0.4453
# Epoch 22: val_loss improved from 2.63067 to 2.48863, saving model to model_checkpoint.h5
# 60/60 [==============================] - 239s 4s/step - loss: 2.1208 - accuracy: 0.4453 - val_loss: 2.4886 - val_accuracy: 0.3989
# Epoch 23/100
# 60/60 [==============================] - ETA: 0s - loss: 2.0138 - accuracy: 0.4453
# Epoch 23: val_loss did not improve from 2.48863
# 60/60 [==============================] - 242s 4s/step - loss: 2.0138 - accuracy: 0.4453 - val_loss: 2.5430 - val_accuracy: 0.4026
# Epoch 24/100
# 60/60 [==============================] - ETA: 0s - loss: 1.9474 - accuracy: 0.4687
# Epoch 24: val_loss did not improve from 2.48863
# 60/60 [==============================] - 239s 4s/step - loss: 1.9474 - accuracy: 0.4687 - val_loss: 2.5360 - val_accuracy: 0.4173
# Epoch 25/100
# 60/60 [==============================] - ETA: 0s - loss: 1.8491 - accuracy: 0.4984
# Epoch 25: val_loss did not improve from 2.48863
# 60/60 [==============================] - 241s 4s/step - loss: 1.8491 - accuracy: 0.4984 - val_loss: 2.7038 - val_accuracy: 0.4154
# Epoch 26/100
# 60/60 [==============================] - ETA: 0s - loss: 1.7981 - accuracy: 0.5099
# Epoch 26: val_loss did not improve from 2.48863
# 60/60 [==============================] - 244s 4s/step - loss: 1.7981 - accuracy: 0.5099 - val_loss: 2.6174 - val_accuracy: 0.4320
# Epoch 27/100
# 60/60 [==============================] - ETA: 0s - loss: 1.7696 - accuracy: 0.5172
# Epoch 27: val_loss did not improve from 2.48863
# 60/60 [==============================] - 222s 4s/step - loss: 1.7696 - accuracy: 0.5172 - val_loss: 2.5580 - val_accuracy: 0.4449
# Epoch 28/100
# 60/60 [==============================] - ETA: 0s - loss: 1.6783 - accuracy: 0.5297
# Epoch 28: val_loss improved from 2.48863 to 2.25240, saving model to model_checkpoint.h5
# 60/60 [==============================] - 220s 4s/step - loss: 1.6783 - accuracy: 0.5297 - val_loss: 2.2524 - val_accuracy: 0.4651
# Epoch 29/100
# 60/60 [==============================] - ETA: 0s - loss: 1.5862 - accuracy: 0.5693
# Epoch 29: val_loss did not improve from 2.25240
# 60/60 [==============================] - 226s 4s/step - loss: 1.5862 - accuracy: 0.5693 - val_loss: 2.3336 - val_accuracy: 0.4669
# Epoch 30/100
# 60/60 [==============================] - ETA: 0s - loss: 1.5965 - accuracy: 0.5704
# Epoch 30: val_loss did not improve from 2.25240
# 60/60 [==============================] - 222s 4s/step - loss: 1.5965 - accuracy: 0.5704 - val_loss: 2.4312 - val_accuracy: 0.4632
# Epoch 31/100
# 60/60 [==============================] - ETA: 0s - loss: 1.4384 - accuracy: 0.6001
# Epoch 31: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 1.4384 - accuracy: 0.6001 - val_loss: 2.3402 - val_accuracy: 0.4596
# Epoch 32/100
# 60/60 [==============================] - ETA: 0s - loss: 1.4574 - accuracy: 0.5912
# Epoch 32: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 1.4574 - accuracy: 0.5912 - val_loss: 2.4037 - val_accuracy: 0.4743
# Epoch 33/100
# 60/60 [==============================] - ETA: 0s - loss: 1.3739 - accuracy: 0.6163
# Epoch 33: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 1.3739 - accuracy: 0.6163 - val_loss: 2.6398 - val_accuracy: 0.4338
# Epoch 34/100
# 60/60 [==============================] - ETA: 0s - loss: 1.3947 - accuracy: 0.6241
# Epoch 34: val_loss did not improve from 2.25240
# 60/60 [==============================] - 219s 4s/step - loss: 1.3947 - accuracy: 0.6241 - val_loss: 2.3529 - val_accuracy: 0.4835
# Epoch 35/100
# 60/60 [==============================] - ETA: 0s - loss: 1.3515 - accuracy: 0.6105
# Epoch 35: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 1.3515 - accuracy: 0.6105 - val_loss: 2.4139 - val_accuracy: 0.4779
# Epoch 36/100
# 60/60 [==============================] - ETA: 0s - loss: 1.3101 - accuracy: 0.6111
# Epoch 36: val_loss did not improve from 2.25240
# 60/60 [==============================] - 219s 4s/step - loss: 1.3101 - accuracy: 0.6111 - val_loss: 2.5919 - val_accuracy: 0.4596
# Epoch 37/100
# 60/60 [==============================] - ETA: 0s - loss: 1.2931 - accuracy: 0.6277
# Epoch 37: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 1.2931 - accuracy: 0.6277 - val_loss: 2.3869 - val_accuracy: 0.4963
# Epoch 38/100
# 60/60 [==============================] - ETA: 0s - loss: 1.1789 - accuracy: 0.6601
# Epoch 38: val_loss did not improve from 2.25240
# 60/60 [==============================] - 219s 4s/step - loss: 1.1789 - accuracy: 0.6601 - val_loss: 2.3657 - val_accuracy: 0.4761
# Epoch 39/100
# 60/60 [==============================] - ETA: 0s - loss: 1.1485 - accuracy: 0.6747
# Epoch 39: val_loss did not improve from 2.25240
# 60/60 [==============================] - 219s 4s/step - loss: 1.1485 - accuracy: 0.6747 - val_loss: 2.5497 - val_accuracy: 0.4743
# Epoch 40/100
# 60/60 [==============================] - ETA: 0s - loss: 1.1712 - accuracy: 0.6731
# Epoch 40: val_loss did not improve from 2.25240
# 60/60 [==============================] - 221s 4s/step - loss: 1.1712 - accuracy: 0.6731 - val_loss: 2.6421 - val_accuracy: 0.4926
# Epoch 41/100
# 60/60 [==============================] - ETA: 0s - loss: 1.1266 - accuracy: 0.6898
# Epoch 41: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 1.1266 - accuracy: 0.6898 - val_loss: 2.3810 - val_accuracy: 0.4982
# Epoch 42/100
# 60/60 [==============================] - ETA: 0s - loss: 1.1463 - accuracy: 0.6752
# Epoch 42: val_loss did not improve from 2.25240
# 60/60 [==============================] - 240s 4s/step - loss: 1.1463 - accuracy: 0.6752 - val_loss: 2.5389 - val_accuracy: 0.4761
# Epoch 43/100
# 60/60 [==============================] - ETA: 0s - loss: 1.0620 - accuracy: 0.6887
# Epoch 43: val_loss did not improve from 2.25240
# 60/60 [==============================] - 231s 4s/step - loss: 1.0620 - accuracy: 0.6887 - val_loss: 2.6439 - val_accuracy: 0.5129
# Epoch 44/100
# 60/60 [==============================] - ETA: 0s - loss: 1.0106 - accuracy: 0.7117
# Epoch 44: val_loss did not improve from 2.25240
# 60/60 [==============================] - 241s 4s/step - loss: 1.0106 - accuracy: 0.7117 - val_loss: 2.6411 - val_accuracy: 0.4926
# Epoch 45/100
# 60/60 [==============================] - ETA: 0s - loss: 1.0359 - accuracy: 0.6966
# Epoch 45: val_loss did not improve from 2.25240
# 60/60 [==============================] - 240s 4s/step - loss: 1.0359 - accuracy: 0.6966 - val_loss: 2.4089 - val_accuracy: 0.5110
# Epoch 46/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9791 - accuracy: 0.7143
# Epoch 46: val_loss did not improve from 2.25240
# 60/60 [==============================] - 239s 4s/step - loss: 0.9791 - accuracy: 0.7143 - val_loss: 2.5116 - val_accuracy: 0.4945
# Epoch 47/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9343 - accuracy: 0.7231
# Epoch 47: val_loss did not improve from 2.25240
# 60/60 [==============================] - 243s 4s/step - loss: 0.9343 - accuracy: 0.7231 - val_loss: 2.5220 - val_accuracy: 0.5147
# Epoch 48/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9947 - accuracy: 0.7195
# Epoch 48: val_loss did not improve from 2.25240
# 60/60 [==============================] - 239s 4s/step - loss: 0.9947 - accuracy: 0.7195 - val_loss: 2.6833 - val_accuracy: 0.4890
# Epoch 49/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9201 - accuracy: 0.7315
# Epoch 49: val_loss did not improve from 2.25240
# 60/60 [==============================] - 237s 4s/step - loss: 0.9201 - accuracy: 0.7315 - val_loss: 2.5901 - val_accuracy: 0.5018
# Epoch 50/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9027 - accuracy: 0.7388
# Epoch 50: val_loss did not improve from 2.25240
# 60/60 [==============================] - 238s 4s/step - loss: 0.9027 - accuracy: 0.7388 - val_loss: 2.6180 - val_accuracy: 0.4890
# Epoch 51/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9083 - accuracy: 0.7466
# Epoch 51: val_loss did not improve from 2.25240
# 60/60 [==============================] - 239s 4s/step - loss: 0.9083 - accuracy: 0.7466 - val_loss: 2.4329 - val_accuracy: 0.5239
# Epoch 52/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9010 - accuracy: 0.7320
# Epoch 52: val_loss did not improve from 2.25240
# 60/60 [==============================] - 240s 4s/step - loss: 0.9010 - accuracy: 0.7320 - val_loss: 2.7134 - val_accuracy: 0.5018
# Epoch 53/100
# 60/60 [==============================] - ETA: 0s - loss: 0.8121 - accuracy: 0.7654
# Epoch 53: val_loss did not improve from 2.25240
# 60/60 [==============================] - 238s 4s/step - loss: 0.8121 - accuracy: 0.7654 - val_loss: 2.5576 - val_accuracy: 0.5202
# Epoch 54/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7995 - accuracy: 0.7659
# Epoch 54: val_loss did not improve from 2.25240
# 60/60 [==============================] - 237s 4s/step - loss: 0.7995 - accuracy: 0.7659 - val_loss: 2.8821 - val_accuracy: 0.5074
# Epoch 55/100
# 60/60 [==============================] - ETA: 0s - loss: 0.8582 - accuracy: 0.7513
# Epoch 55: val_loss did not improve from 2.25240
# 60/60 [==============================] - 239s 4s/step - loss: 0.8582 - accuracy: 0.7513 - val_loss: 2.6546 - val_accuracy: 0.5349
# Epoch 56/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7799 - accuracy: 0.7643
# Epoch 56: val_loss did not improve from 2.25240
# 60/60 [==============================] - 236s 4s/step - loss: 0.7799 - accuracy: 0.7643 - val_loss: 2.6877 - val_accuracy: 0.5221
# Epoch 57/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7923 - accuracy: 0.7633
# Epoch 57: val_loss did not improve from 2.25240
# 60/60 [==============================] - 239s 4s/step - loss: 0.7923 - accuracy: 0.7633 - val_loss: 2.5020 - val_accuracy: 0.5276
# Epoch 58/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7937 - accuracy: 0.7649
# Epoch 58: val_loss did not improve from 2.25240
# 60/60 [==============================] - 241s 4s/step - loss: 0.7937 - accuracy: 0.7649 - val_loss: 2.8306 - val_accuracy: 0.5037
# Epoch 59/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7948 - accuracy: 0.7654
# Epoch 59: val_loss did not improve from 2.25240
# 60/60 [==============================] - 221s 4s/step - loss: 0.7948 - accuracy: 0.7654 - val_loss: 2.7292 - val_accuracy: 0.4890
# Epoch 60/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7945 - accuracy: 0.7763
# Epoch 60: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 0.7945 - accuracy: 0.7763 - val_loss: 3.1591 - val_accuracy: 0.4669
# Epoch 61/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7122 - accuracy: 0.7904
# Epoch 61: val_loss did not improve from 2.25240
# 60/60 [==============================] - 221s 4s/step - loss: 0.7122 - accuracy: 0.7904 - val_loss: 2.7455 - val_accuracy: 0.5202
# Epoch 62/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7209 - accuracy: 0.7873
# Epoch 62: val_loss did not improve from 2.25240
# 60/60 [==============================] - 218s 4s/step - loss: 0.7209 - accuracy: 0.7873 - val_loss: 2.9209 - val_accuracy: 0.5221
# Epoch 63/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7648 - accuracy: 0.7696
# Epoch 63: val_loss did not improve from 2.25240
# 60/60 [==============================] - 222s 4s/step - loss: 0.7648 - accuracy: 0.7696 - val_loss: 2.9084 - val_accuracy: 0.5110
# Epoch 64/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6783 - accuracy: 0.7956
# Epoch 64: val_loss did not improve from 2.25240
# 60/60 [==============================] - 221s 4s/step - loss: 0.6783 - accuracy: 0.7956 - val_loss: 2.8900 - val_accuracy: 0.5221
# Epoch 65/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.8050
# Epoch 65: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 0.6326 - accuracy: 0.8050 - val_loss: 2.6151 - val_accuracy: 0.5404
# Epoch 66/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7492 - accuracy: 0.7774
# Epoch 66: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 0.7492 - accuracy: 0.7774 - val_loss: 2.4962 - val_accuracy: 0.5478
# Epoch 67/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6056 - accuracy: 0.8227
# Epoch 67: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 0.6056 - accuracy: 0.8227 - val_loss: 3.0495 - val_accuracy: 0.5386
# Epoch 68/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6595 - accuracy: 0.8055
# Epoch 68: val_loss did not improve from 2.25240
# 60/60 [==============================] - 221s 4s/step - loss: 0.6595 - accuracy: 0.8055 - val_loss: 2.6888 - val_accuracy: 0.5239
# Epoch 69/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6215 - accuracy: 0.8186
# Epoch 69: val_loss did not improve from 2.25240
# 60/60 [==============================] - 222s 4s/step - loss: 0.6215 - accuracy: 0.8186 - val_loss: 2.7576 - val_accuracy: 0.5404
# Epoch 70/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6643 - accuracy: 0.7987
# Epoch 70: val_loss did not improve from 2.25240
# 60/60 [==============================] - 220s 4s/step - loss: 0.6643 - accuracy: 0.7987 - val_loss: 3.0716 - val_accuracy: 0.5478
# Epoch 71/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6757 - accuracy: 0.8034
# Epoch 71: val_loss did not improve from 2.25240
# 60/60 [==============================] - 221s 4s/step - loss: 0.6757 - accuracy: 0.8034 - val_loss: 2.5305 - val_accuracy: 0.5496
# Epoch 72/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5994 - accuracy: 0.8071
# Epoch 72: val_loss did not improve from 2.25240
# 60/60 [==============================] - 219s 4s/step - loss: 0.5994 - accuracy: 0.8071 - val_loss: 3.0437 - val_accuracy: 0.5239
# Epoch 73/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5909 - accuracy: 0.8076
# Epoch 73: val_loss did not improve from 2.25240
# 60/60 [==============================] - 219s 4s/step - loss: 0.5909 - accuracy: 0.8076 - val_loss: 2.8422 - val_accuracy: 0.5533
# Epoch 74/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6780 - accuracy: 0.7899
# Epoch 74: val_loss did not improve from 2.25240
# 60/60 [==============================] - 219s 4s/step - loss: 0.6780 - accuracy: 0.7899 - val_loss: 2.7751 - val_accuracy: 0.5202
# Epoch 75/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6372 - accuracy: 0.8102
# Epoch 75: val_loss did not improve from 2.25240
# 60/60 [==============================] - 237s 4s/step - loss: 0.6372 - accuracy: 0.8102 - val_loss: 2.9433 - val_accuracy: 0.5184
# Epoch 76/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5993 - accuracy: 0.8201
# Epoch 76: val_loss did not improve from 2.25240
# 60/60 [==============================] - 240s 4s/step - loss: 0.5993 - accuracy: 0.8201 - val_loss: 2.6617 - val_accuracy: 0.5496
# Epoch 77/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5736 - accuracy: 0.8175
# Epoch 77: val_loss did not improve from 2.25240
# 60/60 [==============================] - 241s 4s/step - loss: 0.5736 - accuracy: 0.8175 - val_loss: 2.8995 - val_accuracy: 0.5551
# Epoch 78/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5564 - accuracy: 0.8274
# Epoch 78: val_loss did not improve from 2.25240
# 60/60 [==============================] - 243s 4s/step - loss: 0.5564 - accuracy: 0.8274 - val_loss: 2.8437 - val_accuracy: 0.5735
# Epoch 79/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5428 - accuracy: 0.8279
# Epoch 79: val_loss did not improve from 2.25240
# 60/60 [==============================] - 236s 4s/step - loss: 0.5428 - accuracy: 0.8279 - val_loss: 2.9711 - val_accuracy: 0.5662
# Epoch 80/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5494 - accuracy: 0.8321
# Epoch 80: val_loss did not improve from 2.25240
# 60/60 [==============================] - 240s 4s/step - loss: 0.5494 - accuracy: 0.8321 - val_loss: 3.1605 - val_accuracy: 0.5496
# Epoch 81/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5253 - accuracy: 0.8379
# Epoch 81: val_loss did not improve from 2.25240
# 60/60 [==============================] - 239s 4s/step - loss: 0.5253 - accuracy: 0.8379 - val_loss: 3.1282 - val_accuracy: 0.5515
# Epoch 82/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5978 - accuracy: 0.8253
# Epoch 82: val_loss did not improve from 2.25240
# 60/60 [==============================] - 236s 4s/step - loss: 0.5978 - accuracy: 0.8253 - val_loss: 2.9435 - val_accuracy: 0.5551
# Epoch 83/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5833 - accuracy: 0.8264
# Epoch 83: val_loss did not improve from 2.25240
# 60/60 [==============================] - 240s 4s/step - loss: 0.5833 - accuracy: 0.8264 - val_loss: 3.1889 - val_accuracy: 0.5276
# Epoch 84/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5617 - accuracy: 0.8358
# Epoch 84: val_loss did not improve from 2.25240
# 60/60 [==============================] - 242s 4s/step - loss: 0.5617 - accuracy: 0.8358 - val_loss: 2.8895 - val_accuracy: 0.5533
# Epoch 85/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4863 - accuracy: 0.8478
# Epoch 85: val_loss did not improve from 2.25240
# 60/60 [==============================] - 240s 4s/step - loss: 0.4863 - accuracy: 0.8478 - val_loss: 2.7762 - val_accuracy: 0.5680
# Epoch 86/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5127 - accuracy: 0.8462
# Epoch 86: val_loss did not improve from 2.25240
# 60/60 [==============================] - 238s 4s/step - loss: 0.5127 - accuracy: 0.8462 - val_loss: 3.0697 - val_accuracy: 0.5478
# Epoch 87/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5042 - accuracy: 0.8420
# Epoch 87: val_loss did not improve from 2.25240
# 60/60 [==============================] - 239s 4s/step - loss: 0.5042 - accuracy: 0.8420 - val_loss: 3.3786 - val_accuracy: 0.5551
# Epoch 88/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5369 - accuracy: 0.8306
# Epoch 88: val_loss did not improve from 2.25240
# 60/60 [==============================] - 238s 4s/step - loss: 0.5369 - accuracy: 0.8306 - val_loss: 2.9027 - val_accuracy: 0.5423
# Epoch 89/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4839 - accuracy: 0.8566
# Epoch 89: val_loss did not improve from 2.25240
# 60/60 [==============================] - 240s 4s/step - loss: 0.4839 - accuracy: 0.8566 - val_loss: 2.9899 - val_accuracy: 0.5643
# Epoch 90/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4921 - accuracy: 0.8660
# Epoch 90: val_loss did not improve from 2.25240
# 60/60 [==============================] - 237s 4s/step - loss: 0.4921 - accuracy: 0.8660 - val_loss: 2.8534 - val_accuracy: 0.5570
# Epoch 91/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4363 - accuracy: 0.8665
# Epoch 91: val_loss did not improve from 2.25240
# 60/60 [==============================] - 232s 4s/step - loss: 0.4363 - accuracy: 0.8665 - val_loss: 2.9994 - val_accuracy: 0.5515
# Epoch 92/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5007 - accuracy: 0.8504
# Epoch 92: val_loss did not improve from 2.25240
# 60/60 [==============================] - 237s 4s/step - loss: 0.5007 - accuracy: 0.8504 - val_loss: 2.9756 - val_accuracy: 0.5570
# Epoch 93/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4770 - accuracy: 0.8566
# Epoch 93: val_loss did not improve from 2.25240
# 60/60 [==============================] - 237s 4s/step - loss: 0.4770 - accuracy: 0.8566 - val_loss: 3.0087 - val_accuracy: 0.5515
# Epoch 94/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4964 - accuracy: 0.8540
# Epoch 94: val_loss did not improve from 2.25240
# 60/60 [==============================] - 236s 4s/step - loss: 0.4964 - accuracy: 0.8540 - val_loss: 2.9145 - val_accuracy: 0.5570
# Epoch 95/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5097 - accuracy: 0.8452
# Epoch 95: val_loss did not improve from 2.25240
# 60/60 [==============================] - 237s 4s/step - loss: 0.5097 - accuracy: 0.8452 - val_loss: 2.9822 - val_accuracy: 0.5478
# Epoch 96/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4710 - accuracy: 0.8488
# Epoch 96: val_loss did not improve from 2.25240
# 60/60 [==============================] - 236s 4s/step - loss: 0.4710 - accuracy: 0.8488 - val_loss: 3.0066 - val_accuracy: 0.5570
# Epoch 97/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4535 - accuracy: 0.8629
# Epoch 97: val_loss did not improve from 2.25240
# 60/60 [==============================] - 237s 4s/step - loss: 0.4535 - accuracy: 0.8629 - val_loss: 3.0426 - val_accuracy: 0.5643
# Epoch 98/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4660 - accuracy: 0.8665
# Epoch 98: val_loss did not improve from 2.25240
# 60/60 [==============================] - 235s 4s/step - loss: 0.4660 - accuracy: 0.8665 - val_loss: 2.7751 - val_accuracy: 0.5699
# Epoch 99/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4231 - accuracy: 0.8676
# Epoch 99: val_loss did not improve from 2.25240
# 60/60 [==============================] - 235s 4s/step - loss: 0.4231 - accuracy: 0.8676 - val_loss: 3.1555 - val_accuracy: 0.5478
# Epoch 100/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4126 - accuracy: 0.8670
# Epoch 100: val_loss did not improve from 2.25240
# 60/60 [==============================] - 236s 4s/step - loss: 0.4126 - accuracy: 0.8670 - val_loss: 3.4014 - val_accuracy: 0.5312
# 15/15 [==============================] - 33s 2s/step - loss: 2.6100 - accuracy: 0.5962
# Test Accuracy: 59.62%
# Test Loss: 2.609959840774536

# %%
# Load the saved model
from tensorflow.keras.models import load_model
import cv2
import numpy as np
import os
# Replace 'plant_prediction_model.h5' with the actual path to your saved model file
model_path = 'plant_prediction_model.h5'
trained_model = load_model(model_path)

# Now, you can use the model for prediction on new data
def image_predict(new_image_path):
# Load the plant image
# image_path = 'plant1.jpg'
    

# Example: Load and preprocess a new image for prediction
# new_image_path = '120.jpg'
    img = cv2.imread(new_image_path)
    img = cv2.resize(img, (256, 256))  # Resize for the model's expected input size
    img = img / 255.0  # Normalize pixel values to be between 0 and 1

# Reshape the image to match the input shape expected by the model
    img = img.reshape((1,) + img.shape)

# Make predictions
    predictions = trained_model.predict(img)

# The 'predictions' variable now contains the model's output, which you can interpret as needed
# For example, you can get the predicted class label as follows:
    predicted_class = np.argmax(predictions)

# Display the results
    print("Predicted Class:", predicted_class)
#     print("Predictions (raw output):", predictions)
folder_path = 'C:\\Users\\Amrutha Y\\Desktop\\Train\\Tulsi'
# Iterate through all files in the folder
# for plant in os.listdir(folder_path):
for filename in os.listdir(folder_path):
    if filename.endswith(('.jpg', '.jpeg', '.png')):
        # Load the plant image
#         print(filename)
        image_path = os.path.join(folder_path, filename)
        image_predict(image_path)
# Out:
# 20190822_174503.jpg
# 1/1 [==============================] - 0s 289ms/step
# Predicted Class: 75
# 20190822_174508.jpg
# 1/1 [==============================] - 0s 58ms/step
# Predicted Class: 28
# 20190911_111449.jpg
# 1/1 [==============================] - 0s 48ms/step
# Predicted Class: 21
# 20190911_111854.jpg
# 1/1 [==============================] - 0s 59ms/step
# Predicted Class: 40
# 20190911_122931.jpg
# 1/1 [==============================] - 0s 43ms/step
# Predicted Class: 42
# 20190911_123026.jpg
# 1/1 [==============================] - 0s 56ms/step
# Predicted Class: 5
# 20190916_180938.jpg
# 1/1 [==============================] - 0s 57ms/step
# Predicted Class: 1
# 20190916_180944.jpg
# 1/1 [==============================] - 0s 49ms/step
# Predicted Class: 1
# 20190916_181100.jpg
# 1/1 [==============================] - 0s 52ms/step
# Predicted Class: 5
# 20190916_181131.jpg
# 1/1 [==============================] - 0s 37ms/step
# Predicted Class: 1
# 20190920_182807.jpg
# 1/1 [==============================] - 0s 43ms/step
# Predicted Class: 1
# 20190920_182832.jpg
# 1/1 [==============================] - 0s 38ms/step
# Predicted Class: 21
# 20190920_182913.jpg
# 1/1 [==============================] - 0s 35ms/step
# Predicted Class: 65
# 20190920_182919.jpg
# 1/1 [==============================] - 0s 40ms/step
# Predicted Class: 21
# 20190920_183100.jpg
# 1/1 [==============================] - 0s 37ms/step
# Predicted Class: 75
# 20190920_183250.jpg
# 1/1 [==============================] - 0s 37ms/step
# Predicted Class: 21
# 20190920_183810.jpg
# 1/1 [==============================] - 0s 39ms/step
# Predicted Class: 16
# 20190920_183841.jpg
# 1/1 [==============================] - 0s 37ms/step
# Predicted Class: 52
# IMG_20201003_172039.jpg
# 1/1 [==============================] - 0s 40ms/step
# Predicted Class: 17
# IMG_20201004_185645.jpg
# 1/1 [==============================] - 0s 56ms/step
# Predicted Class: 4
# IMG_20201004_185745__01.jpg
# 1/1 [==============================] - 0s 49ms/step
# Predicted Class: 72
# IMG_20201004_190857__01__01.jpg
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 72
# j.13.jpg
# 1/1 [==============================] - 0s 68ms/step
# Predicted Class: 26
# j.16.jpg
# 1/1 [==============================] - 0s 75ms/step
# Predicted Class: 21
# j.3.jpg
# 1/1 [==============================] - 0s 52ms/step
# Predicted Class: 72
